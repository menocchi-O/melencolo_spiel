# %%
import ipywidgets as widgets
from IPython.display import display

display(widgets.Checkbox(value=True, description="I should appear"))
# Out:
# Checkbox(value=True, description='I should appear')
